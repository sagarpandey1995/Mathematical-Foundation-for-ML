# %% [markdown]
# ## Linear Algebra

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linespace(0, 40, 1000) # start, finish, n points
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t = np.linespace(0, 40, 1000) # start, finish, n points
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\__init__.py:320, in __getattr__(attr)
#     130     raise ImportError(msg) from e
#     132 from . import _core
#     133 from ._core import (
#     134     False_,
#     135     ScalarType,
#     136     True_,
#     137     abs,
#     138     absolute,
#     139     acos,
#     140     acosh,
#     141     add,
#     142     all,
#     143     allclose,
#     144     amax,
#     145     amin,
#     146     any,
#     147     arange,
#     148     arccos,
#     149     arccosh,
#     150     arcsin,
#     151     arcsinh,
#     152     arctan,
#     153     arctan2,
#     154     arctanh,
#     155     argmax,
#     156     argmin,
#     157     argpartition,
# ...
