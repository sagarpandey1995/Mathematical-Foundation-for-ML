# %% [markdown]
# ## Linear Algebra

# %%
t = np.linspace(0, 40, 1000) # start, finish, n points

# %% [markdown]
# ### Example: solving for  unknowns within system of linear equations
# #### Consider the following example
# 1. A has 180 km/h car
# 2. B has 150 km/hr car and five-minute head start
# 3. How long does it take the A to catch B?
# (Note A: 180 km/hr = 3 km/min and B: 150 km/hr = 2.5 km/min)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Suppose at t minutes A catches B so the distance travelled by A and B at t minutes will be
#
# d_b = 2.5t
#
# d_a = 3(t-5)

# %%
d_b = 2.5 * t

# %%
d_a = 3 * (t - 5)

# %%
fig, ax = plt.subplots()
plt.title("A caught B")
plt.xlabel('time (in minutes)')
plt.ylabel('distance (in km)')
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t, d_b, c='green')
ax.plot(t, d_a, c='red')
plt.axvline(x=30, color='purple', linestyle="--")
_=plt.axhline(y=75, color='purple', linestyle="--")
